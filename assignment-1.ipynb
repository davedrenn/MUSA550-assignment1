# %% [markdown]
# # Assignment #1: The Donut Effect for Philadelphia ZIP Codes
#
# In this assignment, we will practice our `pandas` skills and explore the ["Donut Effect"](https://www.gsb.stanford.edu/faculty-research/publications/donut-effect-how-covid-19-shapes-real-estate) within Philadelphia. The "Donut Effect" describes the following phenomenon: with more flexible working options and pandemic-driven density fears, people left urban dense cores and opted for more space in city suburbs, driving home and rental prices up in the suburbs relative to city centers.
#
# We will be working with [Zillow data](https://www.zillow.com/research/data/) for the Zillow Home Value Index (ZHVI) for Philadelphia ZIP codes. The goal will be to calculate home price appreciation in Philadelphia, comparing those ZIP codes in Center City (the central business district) to those not in Center City.

# %% [markdown]
# ## 1. Load the data
#
# I've already downloaded the relevant data file and put in the `data/` folder. Let's load it using `pandas`.
#
# **Note:** Be sure to use a *relative* file path to make it easier to load your data when grading. See [this guide](https://musa-550-fall-2023.github.io/resource/file-paths.html) for more info.

# %%
import pandas as pd

zhviZIP_df = pd.read_csv("data/Zip_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv")

zhviZIP_df.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     91982         3       77494        Zip        TX    TX      Katy
# 4     84616         4       60614        Zip        IL    IL   Chicago
#
#                               Metro       CountyName  2000-01-31  ...  \
# 0       New York-Newark-Jersey City  New York County    329164.0  ...
# 1          Chicago-Naperville-Elgin      Cook County    311718.0  ...
# 2       New York-Newark-Jersey City  New York County    510209.0  ...
# 3  Houston-The Woodlands-Sugar Land    Harris County    224385.0  ...
# 4          Chicago-Naperville-Elgin      Cook County    407594.0  ...
#
#    2021-10-31  2021-11-30  2021-12-31  2022-01-31  2022-02-28  2022-03-31  \
# 0   1153364.0   1152736.0   1153314.0   1159292.0   1171216.0   1190200.0
# 1    523727.0    526511.0    528499.0    529879.0    530092.0    532758.0
# 2   1517150.0   1521442.0   1521759.0   1532449.0   1542269.0   1559390.0
# 3    428419.0    435498.0    441231.0    447322.0    456848.0    468519.0
# 4    669648.0    674293.0    677215.0    679126.0    678889.0    681982.0
#
#    2022-04-30  2022-05-31  2022-06-30  2022-07-31
# 0   1207107.0   1221417.0   1227148.0   1234232.0
# 1    534840.0    539859.0    543658.0    546709.0
# 2   1572653.0   1591368.0   1600569.0   1607770.0
# 3    482272.0    493709.0    501230.0    503505.0
# 4    684421.0    690214.0    695114.0    698644.0
#
# [5 rows x 280 columns]

# %% [markdown]
# ## 2. Trim the data to just Philadelphia
#
# Select the subset of the dataframe for Philadelphia, PA.

# %%
zhviZIP_phl = zhviZIP_df.loc[(zhviZIP_df["State"] == "PA") & (zhviZIP_df["City"] == "Philadelphia")]

zhviZIP_phl
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State  \
# 125       65810       126       19143        Zip        PA    PA
# 247       65779       249       19111        Zip        PA    PA
# 338       65791       340       19124        Zip        PA    PA
# 423       65787       426       19120        Zip        PA    PA
# 509       65772       512       19104        Zip        PA    PA
# 527       65801       530       19134        Zip        PA    PA
# 574       65815       577       19148        Zip        PA    PA
# 623       65798       626       19131        Zip        PA    PA
# 655       65811       658       19144        Zip        PA    PA
# 757       65813       760       19146        Zip        PA    PA
# 783       65812       786       19145        Zip        PA    PA
# 790       65807       793       19140        Zip        PA    PA
# 844       65814       847       19147        Zip        PA    PA
# 889       65816       892       19149        Zip        PA    PA
# 1043      65771      1047       19103        Zip        PA    PA
# 1060      65806      1066       19139        Zip        PA    PA
# 1332      65795      1341       19128        Zip        PA    PA
# 1560      65788      1572       19121        Zip        PA    PA
# 1626      65797      1639       19130        Zip        PA    PA
# 2134      65799      2149       19132        Zip        PA    PA
# 2266      65783      2280       19115        Zip        PA    PA
# 2597      65782      2618       19114        Zip        PA    PA
# 2739      65819      2761       19152        Zip        PA    PA
# 2899      65784      2922       19116        Zip        PA    PA
# 2972      65808      2996       19141        Zip        PA    PA
# 3008      65803      3034       19136        Zip        PA    PA
# 3104      65805      3131       19138        Zip        PA    PA
# 3166      65821      3198       19154        Zip        PA    PA
# 3232      65818      3264       19151        Zip        PA    PA
# 3312      65802      3345       19135        Zip        PA    PA
# 3384      65786      3417       19119        Zip        PA    PA
# 3698      65792      3734       19125        Zip        PA    PA
# 4348      65809      4393       19142        Zip        PA    PA
# 4917      65775      4968       19107        Zip        PA    PA
# 5052      65817      5103       19150        Zip        PA    PA
# 5327      65789      5379       19122        Zip        PA    PA
# 5453      65800      5506       19133        Zip        PA    PA
# 5517      65790      5571       19123        Zip        PA    PA
# 5970      65774      6026       19106        Zip        PA    PA
# 7579      65793      7660       19126        Zip        PA    PA
# 8473      65796      8571       19129        Zip        PA    PA
# 8505      65820      8603       19153        Zip        PA    PA
# 8850      65785      8954       19118        Zip        PA    PA
# 9110      65770      9217       19102        Zip        PA    PA
# 10562     65794     10696       19127        Zip        PA    PA
# 10674     65804     10809       19137        Zip        PA    PA
#
#                City                           Metro           CountyName  \
# 125    Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 247    Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 338    Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 423    Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 509    Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 527    Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 574    Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 623    Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 655    Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 757    Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 783    Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 790    Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 844    Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 889    Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 1043   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 1060   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 1332   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 1560   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 1626   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 2134   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 2266   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 2597   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 2739   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 2899   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 2972   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 3008   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 3104   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 3166   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 3232   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 3312   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 3384   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 3698   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 4348   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 4917   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 5052   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 5327   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 5453   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 5517   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 5970   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 7579   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 8473   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 8505   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 8850   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 9110   Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 10562  Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
# 10674  Philadelphia  Philadelphia-Camden-Wilmington  Philadelphia County
#
#        2000-01-31  ...  2021-10-31  2021-11-30  2021-12-31  2022-01-31  \
# 125       60701.0  ...    173114.0    172087.0    171445.0    171542.0
# 247       85062.0  ...    257911.0    260104.0    262257.0    263715.0
# 338       47155.0  ...    156225.0    157780.0    159029.0    159274.0
# 423       59285.0  ...    161167.0    161807.0    162634.0    162972.0
# 509       74255.0  ...    220270.0    221454.0    222006.0    220760.0
# 527       58238.0  ...    120960.0    122049.0    122368.0    122479.0
# 574       59641.0  ...    269648.0    269225.0    269261.0    268945.0
# [46 rows x 280 columns]

# %% [markdown]
# ## 3. Melt the data into tidy format
#
# Let's transform the data from wide to tidy using the `pd.melt()` function. Create a new column in your data called "ZHVI" that holds the ZHVI values.

# %%
def looks_like_a_date(column_name):
    """A function that tests if a string starts with '20'"""

    return column_name.startswith("20")

zhviZIP_phl_tidy = zhviZIP_phl.melt(
    id_vars=["RegionName"],
    value_vars=list(
        filter(looks_like_a_date, zhviZIP_phl)
    ),
    var_name="Date",
    value_name="ZHVI"
)

zhviZIP_phl_tidy
# Out:
#        RegionName        Date      ZHVI
# 0           19143  2000-01-31   60701.0
# 1           19111  2000-01-31   85062.0
# 2           19124  2000-01-31   47155.0
# 3           19120  2000-01-31   59285.0
# 4           19104  2000-01-31   74255.0
# ...           ...         ...       ...
# 12461       19153  2022-07-31  247560.0
# 12462       19118  2022-07-31  746009.0
# 12463       19102  2022-07-31  347614.0
# 12464       19127  2022-07-31  318732.0
# 12465       19137  2022-07-31  222107.0
#
# [12466 rows x 3 columns]

# %% [markdown]
# ## 4. Split the data for ZIP codes in/outside Center City
#
# To compare home appreciation in Center City vs. outside Center City, we'll need to split the data into two dataframes, one that holds the Center City ZIP codes and one that holds the data for the rest of the ZIP codes in Philadelphia.
#
# To help with this process, I've included a list of ZIP codes that make up the "greater Center City" region of Philadelphia. Use this list to split the melted data into two dataframes.

# %%
greater_center_city_zip_codes = [
    19123,
    19102,
    19103,
    19106,
    19107,
    19109,
    19130,
    19146,
    19147,
]

# %%
greaterCC_ZIP_sel = zhviZIP_phl_tidy["RegionName"].isin(greater_center_city_zip_codes)

CC_ZIP=zhviZIP_phl_tidy.loc[greaterCC_ZIP_sel]
                            
CC_ZIP
# Out:
#        RegionName        Date      ZHVI
# 9           19146  2000-01-31   97460.0
# 12          19147  2000-01-31  119919.0
# 14          19103  2000-01-31  183436.0
# 18          19130  2000-01-31  128477.0
# 33          19107  2000-01-31  128049.0
# ...           ...         ...       ...
# 12438       19130  2022-07-31  431501.0
# 12453       19107  2022-07-31  330958.0
# 12457       19123  2022-07-31  443152.0
# 12458       19106  2022-07-31  407423.0
# 12463       19102  2022-07-31  347614.0
#
# [2168 rows x 3 columns]

# %%
notCC_ZIP=zhviZIP_phl_tidy.loc[zhviZIP_phl_tidy["RegionName"] != greaterCC_ZIP_sel]

notCC_ZIP
# Out:
#        RegionName        Date      ZHVI
# 0           19143  2000-01-31   60701.0
# 1           19111  2000-01-31   85062.0
# 2           19124  2000-01-31   47155.0
# 3           19120  2000-01-31   59285.0
# 4           19104  2000-01-31   74255.0
# ...           ...         ...       ...
# 12461       19153  2022-07-31  247560.0
# 12462       19118  2022-07-31  746009.0
# 12463       19102  2022-07-31  347614.0
# 12464       19127  2022-07-31  318732.0
# 12465       19137  2022-07-31  222107.0
#
# [12466 rows x 3 columns]

# %% [markdown]
# ## 5. Compare home value appreciation in Philadelpia
#
# In this step, we'll calculate the average percent increase in ZHVI from March 2020 to March 2022 for ZIP codes in/out of Center City. We'll do this by:
#
# - Writing a function (see the template below) that will calculate the percent increase in ZHVI from March 31, 2020 to March 31, 2022
# - Group your data and apply this function to calculate the ZHVI percent change for each ZIP code in Philadelphia. Do this for both of your dataframes from the previous step.
# - Calculate the average value across ZIP codes for both sets of ZIP codes and then compare
#
# You should see much larger growth for ZIP codes outside of Center City...the Donut Effect!

# %%
def calculate_percent_increase(group_df):
    """
    Calculate the percent increase from 2020-03-31 to 2022-03-31.
    
    Note that `group_df` is the DataFrame for each group.
    """
    
    march20_sel = group_df["Date"] == "2020-03-31"
    march22_sel = group_df["Date"] == "2022-03-31"
    
    march_2020 = group_df.loc[march20_sel].squeeze()
    march_2022 = group_df.loc[march22_sel].squeeze()

    # Columns to calculate percent change for
    zhvi = ["ZHVI"]
    
    # Return the percent change for both columns
    return 100 * (march_2022[zhvi] / march_2020[zhvi] - 1)

# %%
CC_grouped = CC_ZIP.groupby("RegionName")

CC_change = CC_grouped.apply(calculate_percent_increase)

CC_change
# Out:
#                 ZHVI
# RegionName
# 19102      -1.716711
# 19103      -1.696176
# 19106       2.520802
# 19107       2.883181
# 19123       5.212747
# 19130       6.673031
# 19146       6.480788
# 19147       6.139806

# %%
notCC_grouped = notCC_ZIP.groupby("RegionName")

notCC_change = notCC_grouped.apply(calculate_percent_increase)

notCC_change
# Out:
#                  ZHVI
# RegionName
# 19102       -1.716711
# 19103       -1.696176
# 19104       14.539797
# 19106        2.520802
# 19107        2.883181
# 19111       28.690446
# 19114       21.074312
# 19115       22.455454
# 19116       23.079842
# 19118       17.585001
# 19119       17.478667
# 19120       26.927423
# 19121       26.228643
# 19122       10.275804
# 19123        5.212747
# 19124       28.743474
# 19125       11.007135
# 19126       20.819254
# 19127       20.023926
# 19128       21.887555
# 19129       15.598565
# 19130        6.673031
# 19131       23.363129
# 19132       72.218386
# 19133       36.143992
# 19134       23.936841
# 19135       28.115259
# 19136       26.487833
# 19137       23.248505
# 19138       24.662626
# 19139       37.008969
# 19140       57.150847
# 19141       26.441684
# 19142       44.564396
# 19143       23.951077
# 19144       21.094020
# 19145        7.634693
# 19146        6.480788
# 19147        6.139806
# 19148        6.963237
# 19149       24.916458
# 19150       18.735248
# 19151       19.651429
# 19152       21.993528
# 19153       38.240461
# 19154       17.930932

# %%
avgCC = CC_change.mean().squeeze()
avgCC
# Out:
# 3.3121833477945413

# %%
avgNotCC = notCC_change.mean().squeeze()
avgNotCC
# Out:
# 21.247093794875617

# %%
if avgCC > avgNotCC:
    print(f"Center City had higher growth than surrounding city zipcodes at {avgCC:.1f}% vs. {avgNotCC:.1f}%")
else:
    print(f"Zipcodes outside of Center City had higher growth than Center city at {avgNotCC:.1f}% vs. {avgCC:.1f}%")
# Out:
# Zipcodes outside of Center City had higher growth than Center city at 21.2% vs. 3.3%
